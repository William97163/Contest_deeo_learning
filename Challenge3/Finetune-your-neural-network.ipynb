# %% [markdown]
# # Finetune your Neural Network
#
# **Exercise objectives:**
# - `Finetune` the model optimizer
# - `Save` and `Load` a `trained neural network`
#
# <hr>
#
# Now that you have solid foundations of what Neural Networks, how to design their architecture and how to regularize them, let's take a closer look at the `.compile(loss = ..., metrics = ..., activation = ...)` part.
#
# # Data
#
# We will use the data from the `Boston Housing dataset`.
#
# Our goal is to `predict the values of the houses` (in k USD), and we will measure our models' performances  using the `Mean Absolute Error` metrics

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import boston_housing
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()
X_train.shape
sns.histplot(y_train)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
pd.DataFrame(X_train).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       404 non-null    float64
#  1   1       404 non-null    float64
#  2   2       404 non-null    float64
#  3   3       404 non-null    float64
#  4   4       404 non-null    float64
#  5   5       404 non-null    float64
#  6   6       404 non-null    float64
#  7   7       404 non-null    float64
#  8   8       404 non-null    float64
#  9   9       404 non-null    float64
#  10  10      404 non-null    float64
#  11  11      404 non-null    float64
#  12  12      404 non-null    float64
# dtypes: float64(13)
# memory usage: 41.2 KB

# %%
pd.DataFrame(X_train).describe()
# Out:
#                0           1           2           3           4           5   \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.745111   11.480198   11.104431    0.061881    0.557356    6.267082
# std      9.240734   23.767711    6.811308    0.241238    0.117293    0.709788
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081437    0.000000    5.130000    0.000000    0.453000    5.874750
# 50%      0.268880    0.000000    9.690000    0.000000    0.538000    6.198500
# 75%      3.674808   12.500000   18.100000    0.000000    0.631000    6.609000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.725000
#
#                6           7           8           9           10          11  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.010644    3.740271    9.440594  405.898515   18.475990  354.783168
# std     27.940665    2.030215    8.698360  166.374543    2.200382   94.111148
# min      2.900000    1.129600    1.000000  188.000000   12.600000    0.320000
# 25%     45.475000    2.077100    4.000000  279.000000   17.225000  374.672500
# 50%     78.500000    3.142300    5.000000  330.000000   19.100000  391.250000
# 75%     94.100000    5.118000   24.000000  666.000000   20.200000  396.157500
# max    100.000000   10.710300   24.000000  711.000000   22.000000  396.900000
#
#                12
# count  404.000000
# mean    12.740817
# std      7.254545
# min      1.730000
# 25%      6.890000
# 50%     11.395000
# 75%     17.092500
# max     37.970000

# %% [markdown]
# ❓ **Question** ❓ Standardize `X_train` and `X_test` set without data leakage, and replace them keeping similar variable names

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

scaler_Train = StandardScaler()
scaler_Test = StandardScaler()

scaler_Train.fit(X_train)
scaler_Test.fit(X_test)

X_train = scaler_Train.transform(X_train)
X_test = scaler_Test.transform(X_test)

# %% [markdown]
# ❓ **Question** ❓ To get a sense of a benchmark score you have to beat, what is the mean absolute error on the test set if your dumb prediction corresponds to the mean value of $y$ computed on the train set?

# %% [markdown]
# # 1. The model
#
# ❓ **Question** ❓ Now, write a function `initialize_model` that generates a neural network with 3 layers:
# - a layer with 10 neurons and the `relu` activation function (choose the appropriate input dimension)
# - a layer with 7 neurons and the `relu` activation function
# - an appropriate layer corresponding to the problem at hand

# %%
from tensorflow import keras
from tensorflow.keras import layers

def initialize_model():
    
    model = keras.Sequential()
    model.add(layers.Dense(10, activation="relu", input_dim=13))
    model.add(layers.Dense(7, activation="relu"))
    model.add(layers.Dense(1, activation="linear"))
    
    return model

# %% [markdown]
# # 2. The optimizer
#
# ❓ **Question** ❓ Write a function that :
# * takes as arguments a model and an optimizer,
# * `compiles` the model,
# * and returns the compiled model
#
# Please select the `loss function` to be optimized and  the `metrics` on which the model should be evaluated wisely.

# %%
def compile_model(model, optimizer_name):
    
    model.compile(loss='mean_squared_error', metrics=['accuracy','mae','mse'], optimizer= optimizer_name)
    
    return model

# %% [markdown]
# ❓ **Question** ❓ Initialize the model, compile it with the `adam` optimizer and fit it on the data.
# - Evaluate your model using an Early Stopping criterion.

# %%
model = compile_model(initialize_model(), "adam")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                140
#
#  dense_1 (Dense)             (None, 7)                 77
#
#  dense_2 (Dense)             (None, 1)                 8
#
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

callback = EarlyStopping(
    patience=10, 
    restore_best_weights=True
)

# %%
model.fit(X_train, y_train, validation_split=0.33, epochs=1000, callbacks=[callback])
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 1s 41ms/step - loss: 598.1064 - accuracy: 0.0000e+00 - mae: 22.7858 - mse: 598.1064 - val_loss: 686.7458 - val_accuracy: 0.0000e+00 - val_mae: 24.1882 - val_mse: 686.7458
# Epoch 2/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 590.4660 - accuracy: 0.0000e+00 - mae: 22.6292 - mse: 590.4660 - val_loss: 679.3284 - val_accuracy: 0.0000e+00 - val_mae: 24.0416 - val_mse: 679.3284
# Epoch 3/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 583.8735 - accuracy: 0.0000e+00 - mae: 22.4899 - mse: 583.8735 - val_loss: 672.8354 - val_accuracy: 0.0000e+00 - val_mae: 23.9130 - val_mse: 672.8354
# Epoch 4/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 577.9603 - accuracy: 0.0000e+00 - mae: 22.3656 - mse: 577.9603 - val_loss: 666.9503 - val_accuracy: 0.0000e+00 - val_mae: 23.7953 - val_mse: 666.9503
# Epoch 5/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 572.3721 - accuracy: 0.0000e+00 - mae: 22.2474 - mse: 572.3721 - val_loss: 661.6005 - val_accuracy: 0.0000e+00 - val_mae: 23.6879 - val_mse: 661.6005
# Epoch 6/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 567.3939 - accuracy: 0.0000e+00 - mae: 22.1407 - mse: 567.3939 - val_loss: 656.5989 - val_accuracy: 0.0000e+00 - val_mae: 23.5875 - val_mse: 656.5989
# Epoch 126/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 18.2191 - accuracy: 0.0000e+00 - mae: 3.0236 - mse: 18.2191 - val_loss: 28.4648 - val_accuracy: 0.0000e+00 - val_mae: 3.6684 - val_mse: 28.4648
# Epoch 127/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 18.0910 - accuracy: 0.0000e+00 - mae: 3.0114 - mse: 18.0910 - val_loss: 28.3078 - val_accuracy: 0.0000e+00 - val_mae: 3.6545 - val_mse: 28.3078
# Epoch 128/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 17.9634 - accuracy: 0.0000e+00 - mae: 3.0016 - mse: 17.9634 - val_loss: 28.0652 - val_accuracy: 0.0000e+00 - val_mae: 3.6362 - val_mse: 28.0652
# Epoch 129/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 17.8499 - accuracy: 0.0000e+00 - mae: 3.0043 - mse: 17.8499 - val_loss: 27.5800 - val_accuracy: 0.0000e+00 - val_mae: 3.6138 - val_mse: 27.5800
# Epoch 130/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 17.7086 - accuracy: 0.0000e+00 - mae: 3.0029 - mse: 17.7086 - val_loss: 27.3219 - val_accuracy: 0.0000e+00 - val_mae: 3.5997 - val_mse: 27.3219
# Epoch 131/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 17.5887 - accuracy: 0.0000e+00 - mae: 2.9978 - mse: 17.5887 - val_loss: 27.1726 - val_accuracy: 0.0000e+00 - val_mae: 3.5934 - val_mse: 27.1726
# Epoch 132/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 17.4611 - accuracy: 0.0000e+00 - mae: 2.9852 - mse: 17.4611 - val_loss: 27.0100 - val_accuracy: 0.0000e+00 - val_mae: 3.5798 - val_mse: 27.0100
# Epoch 133/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 17.3602 - accuracy: 0.0000e+00 - mae: 2.9721 - mse: 17.3602 - val_loss: 26.9440 - val_accuracy: 0.0000e+00 - val_mae: 3.5717 - val_mse: 26.9440
# Epoch 134/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 17.2613 - accuracy: 0.0000e+00 - mae: 2.9612 - mse: 17.2613 - val_loss: 26.8131 - val_accuracy: 0.0000e+00 - val_mae: 3.5608 - val_mse: 26.8131
# Epoch 135/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 17.1358 - accuracy: 0.0000e+00 - mae: 2.9517 - mse: 17.1358 - val_loss: 26.7157 - val_accuracy: 0.0000e+00 - val_mae: 3.5529 - val_mse: 26.7157
# Epoch 136/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 17.1177 - accuracy: 0.0000e+00 - mae: 2.9442 - mse: 17.1177 - val_loss: 26.6153 - val_accuracy: 0.0000e+00 - val_mae: 3.5554 - val_mse: 26.6153
# Epoch 137/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 16.9448 - accuracy: 0.0000e+00 - mae: 2.9272 - mse: 16.9448 - val_loss: 26.4277 - val_accuracy: 0.0000e+00 - val_mae: 3.5378 - val_mse: 26.4277
# Epoch 138/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 16.8418 - accuracy: 0.0000e+00 - mae: 2.9191 - mse: 16.8418 - val_loss: 26.3767 - val_accuracy: 0.0000e+00 - val_mae: 3.5317 - val_mse: 26.3767
# Epoch 139/1000
# 9/9 [==============================] - 0s 10ms/step - loss: 16.7395 - accuracy: 0.0000e+00 - mae: 2.9105 - mse: 16.7395 - val_loss: 26.2021 - val_accuracy: 0.0000e+00 - val_mae: 3.5203 - val_mse: 26.2021
# Epoch 140/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 16.6759 - accuracy: 0.0000e+00 - mae: 2.9069 - mse: 16.6759 - val_loss: 26.0229 - val_accuracy: 0.0000e+00 - val_mae: 3.5163 - val_mse: 26.0229
# Epoch 141/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 16.5197 - accuracy: 0.0000e+00 - mae: 2.8931 - mse: 16.5197 - val_loss: 25.9124 - val_accuracy: 0.0000e+00 - val_mae: 3.5062 - val_mse: 25.9124
# Epoch 142/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 16.4261 - accuracy: 0.0000e+00 - mae: 2.8846 - mse: 16.4261 - val_loss: 25.7509 - val_accuracy: 0.0000e+00 - val_mae: 3.4974 - val_mse: 25.7509
# Epoch 143/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 16.3154 - accuracy: 0.0000e+00 - mae: 2.8756 - mse: 16.3154 - val_loss: 25.5578 - val_accuracy: 0.0000e+00 - val_mae: 3.4832 - val_mse: 25.5578
# Epoch 144/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 16.2036 - accuracy: 0.0000e+00 - mae: 2.8667 - mse: 16.2036 - val_loss: 25.4623 - val_accuracy: 0.0000e+00 - val_mae: 3.4759 - val_mse: 25.4623
# Epoch 145/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 16.1024 - accuracy: 0.0000e+00 - mae: 2.8584 - mse: 16.1024 - val_loss: 25.2416 - val_accuracy: 0.0000e+00 - val_mae: 3.4601 - val_mse: 25.2416
# Epoch 146/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 15.9889 - accuracy: 0.0000e+00 - mae: 2.8546 - mse: 15.9889 - val_loss: 25.1296 - val_accuracy: 0.0000e+00 - val_mae: 3.4551 - val_mse: 25.1296
# Epoch 147/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 15.8975 - accuracy: 0.0000e+00 - mae: 2.8467 - mse: 15.8975 - val_loss: 24.9925 - val_accuracy: 0.0000e+00 - val_mae: 3.4510 - val_mse: 24.9925
# Epoch 148/1000
# 9/9 [==============================] - 0s 9ms/step - loss: 15.7851 - accuracy: 0.0000e+00 - mae: 2.8382 - mse: 15.7851 - val_loss: 24.8361 - val_accuracy: 0.0000e+00 - val_mae: 3.4404 - val_mse: 24.8361
# Epoch 149/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 15.6933 - accuracy: 0.0000e+00 - mae: 2.8300 - mse: 15.6933 - val_loss: 24.6737 - val_accuracy: 0.0000e+00 - val_mae: 3.4329 - val_mse: 24.6737
# 9/9 [==============================] - 0s 7ms/step - loss: 13.6834 - accuracy: 0.0000e+00 - mae: 2.6435 - mse: 13.6834 - val_loss: 22.0163 - val_accuracy: 0.0000e+00 - val_mae: 3.2315 - val_mse: 22.0163
# Epoch 174/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 13.6097 - accuracy: 0.0000e+00 - mae: 2.6362 - mse: 13.6097 - val_loss: 21.9200 - val_accuracy: 0.0000e+00 - val_mae: 3.2218 - val_mse: 21.9200
# Epoch 175/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 13.5428 - accuracy: 0.0000e+00 - mae: 2.6322 - mse: 13.5428 - val_loss: 21.8104 - val_accuracy: 0.0000e+00 - val_mae: 3.2122 - val_mse: 21.8104
# Epoch 176/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 13.4611 - accuracy: 0.0000e+00 - mae: 2.6246 - mse: 13.4611 - val_loss: 21.7453 - val_accuracy: 0.0000e+00 - val_mae: 3.2165 - val_mse: 21.7453
# Epoch 177/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 13.3884 - accuracy: 0.0000e+00 - mae: 2.6179 - mse: 13.3884 - val_loss: 21.6701 - val_accuracy: 0.0000e+00 - val_mae: 3.2102 - val_mse: 21.6701
# Epoch 178/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 13.3491 - accuracy: 0.0000e+00 - mae: 2.6141 - mse: 13.3491 - val_loss: 21.5525 - val_accuracy: 0.0000e+00 - val_mae: 3.2098 - val_mse: 21.5525
# Epoch 179/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 13.2527 - accuracy: 0.0000e+00 - mae: 2.6026 - mse: 13.2527 - val_loss: 21.5627 - val_accuracy: 0.0000e+00 - val_mae: 3.2063 - val_mse: 21.5627
# Epoch 180/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 13.1995 - accuracy: 0.0000e+00 - mae: 2.5946 - mse: 13.1995 - val_loss: 21.4500 - val_accuracy: 0.0000e+00 - val_mae: 3.1976 - val_mse: 21.4500
# Epoch 181/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 13.1256 - accuracy: 0.0000e+00 - mae: 2.5889 - mse: 13.1256 - val_loss: 21.1932 - val_accuracy: 0.0000e+00 - val_mae: 3.1801 - val_mse: 21.1932
# Epoch 182/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 13.0382 - accuracy: 0.0000e+00 - mae: 2.5906 - mse: 13.0382 - val_loss: 21.0571 - val_accuracy: 0.0000e+00 - val_mae: 3.1700 - val_mse: 21.0571
# Epoch 183/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 12.9753 - accuracy: 0.0000e+00 - mae: 2.5825 - mse: 12.9753 - val_loss: 20.9818 - val_accuracy: 0.0000e+00 - val_mae: 3.1610 - val_mse: 20.9818
# Epoch 184/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 12.8860 - accuracy: 0.0000e+00 - mae: 2.5742 - mse: 12.8860 - val_loss: 20.8209 - val_accuracy: 0.0000e+00 - val_mae: 3.1452 - val_mse: 20.8209
# Epoch 185/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 12.8210 - accuracy: 0.0000e+00 - mae: 2.5702 - mse: 12.8210 - val_loss: 20.7381 - val_accuracy: 0.0000e+00 - val_mae: 3.1371 - val_mse: 20.7381
# Epoch 186/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 12.7538 - accuracy: 0.0000e+00 - mae: 2.5642 - mse: 12.7538 - val_loss: 20.7283 - val_accuracy: 0.0000e+00 - val_mae: 3.1387 - val_mse: 20.7283
# Epoch 187/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 12.6915 - accuracy: 0.0000e+00 - mae: 2.5602 - mse: 12.6915 - val_loss: 20.6047 - val_accuracy: 0.0000e+00 - val_mae: 3.1362 - val_mse: 20.6047
# Epoch 188/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 12.6310 - accuracy: 0.0000e+00 - mae: 2.5569 - mse: 12.6310 - val_loss: 20.4789 - val_accuracy: 0.0000e+00 - val_mae: 3.1243 - val_mse: 20.4789
# Epoch 189/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 12.5598 - accuracy: 0.0000e+00 - mae: 2.5499 - mse: 12.5598 - val_loss: 20.4008 - val_accuracy: 0.0000e+00 - val_mae: 3.1121 - val_mse: 20.4008
# Epoch 190/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 12.5236 - accuracy: 0.0000e+00 - mae: 2.5422 - mse: 12.5236 - val_loss: 20.3876 - val_accuracy: 0.0000e+00 - val_mae: 3.0976 - val_mse: 20.3876
# Epoch 191/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 12.4294 - accuracy: 0.0000e+00 - mae: 2.5332 - mse: 12.4294 - val_loss: 20.3198 - val_accuracy: 0.0000e+00 - val_mae: 3.0965 - val_mse: 20.3198
# Epoch 192/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 12.3668 - accuracy: 0.0000e+00 - mae: 2.5280 - mse: 12.3668 - val_loss: 20.2591 - val_accuracy: 0.0000e+00 - val_mae: 3.0932 - val_mse: 20.2591
# Epoch 193/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 12.3322 - accuracy: 0.0000e+00 - mae: 2.5293 - mse: 12.3322 - val_loss: 20.2229 - val_accuracy: 0.0000e+00 - val_mae: 3.0950 - val_mse: 20.2229
# Epoch 194/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 12.2475 - accuracy: 0.0000e+00 - mae: 2.5210 - mse: 12.2475 - val_loss: 20.0764 - val_accuracy: 0.0000e+00 - val_mae: 3.0725 - val_mse: 20.0764
# Epoch 195/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 12.1950 - accuracy: 0.0000e+00 - mae: 2.5144 - mse: 12.1950 - val_loss: 19.9733 - val_accuracy: 0.0000e+00 - val_mae: 3.0618 - val_mse: 19.9733
# Epoch 196/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 12.1370 - accuracy: 0.0000e+00 - mae: 2.5103 - mse: 12.1370 - val_loss: 19.8474 - val_accuracy: 0.0000e+00 - val_mae: 3.0517 - val_mse: 19.8474
# Epoch 197/1000
# Epoch 295/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2899 - accuracy: 0.0000e+00 - mae: 2.1520 - mse: 8.2899 - val_loss: 15.8021 - val_accuracy: 0.0000e+00 - val_mae: 2.6572 - val_mse: 15.8021
# Epoch 296/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2755 - accuracy: 0.0000e+00 - mae: 2.1488 - mse: 8.2755 - val_loss: 15.7881 - val_accuracy: 0.0000e+00 - val_mae: 2.6592 - val_mse: 15.7881
# Epoch 297/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2499 - accuracy: 0.0000e+00 - mae: 2.1466 - mse: 8.2499 - val_loss: 15.8037 - val_accuracy: 0.0000e+00 - val_mae: 2.6634 - val_mse: 15.8037
# Epoch 298/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 8.2263 - accuracy: 0.0000e+00 - mae: 2.1470 - mse: 8.2263 - val_loss: 15.8003 - val_accuracy: 0.0000e+00 - val_mae: 2.6635 - val_mse: 15.8003
# Epoch 299/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.2542 - accuracy: 0.0000e+00 - mae: 2.1473 - mse: 8.2542 - val_loss: 15.8120 - val_accuracy: 0.0000e+00 - val_mae: 2.6488 - val_mse: 15.8120
# Epoch 300/1000
# 9/9 [==============================] - 0s 8ms/step - loss: 8.1972 - accuracy: 0.0000e+00 - mae: 2.1387 - mse: 8.1972 - val_loss: 15.7365 - val_accuracy: 0.0000e+00 - val_mae: 2.6446 - val_mse: 15.7365
# Epoch 301/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1693 - accuracy: 0.0000e+00 - mae: 2.1392 - mse: 8.1693 - val_loss: 15.6155 - val_accuracy: 0.0000e+00 - val_mae: 2.6447 - val_mse: 15.6155
# Epoch 302/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1593 - accuracy: 0.0000e+00 - mae: 2.1484 - mse: 8.1593 - val_loss: 15.6190 - val_accuracy: 0.0000e+00 - val_mae: 2.6534 - val_mse: 15.6190
# Epoch 303/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.1143 - accuracy: 0.0000e+00 - mae: 2.1406 - mse: 8.1143 - val_loss: 15.5903 - val_accuracy: 0.0000e+00 - val_mae: 2.6484 - val_mse: 15.5903
# Epoch 304/1000
# 9/9 [==============================] - 0s 7ms/step - loss: 8.0915 - accuracy: 0.0000e+00 - mae: 2.1361 - mse: 8.0915 - val_loss: 15.5841 - val_accuracy: 0.0000e+00 - val_mae: 2.6413 - val_mse: 15.5841
# Epoch 305/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.0807 - accuracy: 0.0000e+00 - mae: 2.1285 - mse: 8.0807 - val_loss: 15.5762 - val_accuracy: 0.0000e+00 - val_mae: 2.6349 - val_mse: 15.5762
# Epoch 306/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 8.0520 - accuracy: 0.0000e+00 - mae: 2.1212 - mse: 8.0520 - val_loss: 15.5952 - val_accuracy: 0.0000e+00 - val_mae: 2.6405 - val_mse: 15.5952
# 9/9 [==============================] - 0s 6ms/step - loss: 7.1301 - accuracy: 0.0000e+00 - mae: 1.9962 - mse: 7.1301 - val_loss: 15.1503 - val_accuracy: 0.0000e+00 - val_mae: 2.5856 - val_mse: 15.1503
# Epoch 355/1000
# 9/9 [==============================] - 0s 6ms/step - loss: 7.1208 - accuracy: 0.0000e+00 - mae: 1.9949 - mse: 7.1208 - val_loss: 15.2053 - val_accuracy: 0.0000e+00 - val_mae: 2.5995 - val_mse: 15.2053

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 16.8182 - accuracy: 0.0000e+00 - mae: 2.8907 - mse: 16.8182

# %%
model.history.history
# Out:
# {}

# %% [markdown]
# ❓ **Question** ❓ Re-run the same model on the same data using different optimizers (in a `for` loop).
#
# For each optimizer, plot the history and report the corresponding Mean Absolute Error. (see [here](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)), as well as the time it took to fit your Neural Net.

# %%
def plot_loss_mae(history):
        
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,4))
    ax1.plot(history.history['loss'])
    ax1.plot(history.history['val_loss'])
    ax1.set_title('Model loss')
    ax1.set_ylabel('Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylim(ymin=0, ymax=200)
    ax1.legend(['Train', 'Validation'], loc='best')
    ax1.grid(axis="x",linewidth=0.5)
    ax1.grid(axis="y",linewidth=0.5)    

    ax2.plot(history.history['mae'])
    ax2.plot(history.history['val_mae'])
    ax2.set_title('MAE')
    ax2.set_ylabel('MAE')
    ax2.set_xlabel('Epoch')
    ax2.set_ylim(ymin=0, ymax=20)
    ax2.legend(['Train', 'Validation'], loc='best')
    ax2.grid(axis="x",linewidth=0.5)
    ax2.grid(axis="y",linewidth=0.5)    

    plt.show()

def plot_loss_mse(history):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,4))
    ax1.plot(history.history['loss'])
    ax1.plot(history.history['val_loss'])
    ax1.set_title('Model loss')
    ax1.set_ylabel('Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylim(ymin=0, ymax=20)
    ax1.legend(['Train', 'Validation'], loc='best')
    ax1.grid(axis="x",linewidth=0.5)
    ax1.grid(axis="y",linewidth=0.5)    

    
    ax2.plot(history.history['mse'])
    ax2.plot(history.history['val_mse'])
    ax2.set_title('MSE')
    ax2.set_ylabel('MSE')
    ax2.set_xlabel('Epoch')
    ax2.set_ylim(ymin=0, ymax=200)
    ax2.legend(['Train', 'Validation'], loc='best')
    ax2.grid(axis="x",linewidth=0.5)
    ax2.grid(axis="y",linewidth=0.5)    

    plt.show()

# %%
import time

for optimizer in ['rmsprop', 'adam', 'adagrad']:
    start_time = time.time()
    model = initialize_model()
    model = compile_model(model, optimizer)

    es = EarlyStopping(patience=10, restore_best_weights=True)

    history = model.fit(X_train, y_train, 
                      batch_size=16, 
                      epochs=500, 
                      validation_split=0.3,
                      callbacks=[es], verbose=0)

    res = model.evaluate(X_test, y_test)[1]
    end_time = time.time()

    print(f'MAE with the {optimizer} optimizer: {res:.4f}  reached in {(end_time - start_time):.0f} s after {len(history.epoch)} epochs')
    plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 7ms/step - loss: 19.4796 - accuracy: 0.0000e+00 - mae: 2.8875 - mse: 19.4796
# MAE with the rmsprop optimizer: 0.0000  reached in 11 s after 194 epochs
# 4/4 [==============================] - 0s 3ms/step - loss: 19.2864 - accuracy: 0.0000e+00 - mae: 2.8758 - mse: 19.2864
# MAE with the adam optimizer: 0.0000  reached in 18 s after 315 epochs
# 4/4 [==============================] - 0s 2ms/step - loss: 408.7296 - accuracy: 0.0000e+00 - mae: 18.1095 - mse: 408.7296
# MAE with the adagrad optimizer: 0.0000  reached in 28 s after 500 epochs

# %% [markdown]
# ❓ **Question** ❓ Are your predictions better than the benchmark model you've evaluated at the beginning of the notebook?

# %% [markdown]
# ❗ **Remark** ❗
# - Here, the optimizer is may not be central as the data are in low dimensions and and there are not many samples. However, in practice, you are advised to start with the `adam` optimizer by default which often works best.
#
# - Internally, when you call any optimizer with a string, the neural network initializes the hyperparameters the optimizer relies on. Among this hyperparameters, there is quite an important one, the **`learning rate`**. This learning rate corresponds to the intensity of change of the weights at each optimization of the neural network. Different learning rates have different consequences, as shown here :
#
# <img src="learning_rate.png" alt="Learning rate" style="height:350px;"/>
#
#
# As the learning rate is initialized with default values when you compile the model optimizer with a string, let's see how to do it differently.
#
#
# ❓ **Question** ❓ Instead of initializing the optimizer with a string, we will initialize a real optimizer directly. Look at the documentation of [adam](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam) and instantiate it with a learning rate of $0.1$ - keep the other values to their default values. Use this optimizer in the `compile_model` function, fit the data and plot the history

# %%
from tensorflow.keras import optimizers

start_time = time.time()

model = initialize_model()
optimizer = optimizers.Adam(learning_rate=0.1)
compile_model(model, optimizer)

es = EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, 
                  batch_size=16, 
                  epochs=500, 
                  validation_split=0.3,
                  callbacks=[es], verbose=0)

res = model.evaluate(X_test, y_test)[1]

print(f'MAE with the {optimizer} optimizer: {res:.4f}  reached in {(end_time - start_time):.0f} s after {len(history.epoch)} epochs')
plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 18.1618 - accuracy: 0.0000e+00 - mae: 2.8393 - mse: 18.1618
# MAE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CD8436DF0> optimizer: 0.0000  reached in -78 s after 29 epochs

# %% [markdown]
# ❓ **Question** ❓ Now, reproduce the same plots and results but for different learning rates.
#
# *Remark*: There is a chance that the y-axis is too large for you to visualize the results. In that case, rewrite the plot function to plot only the epochs > 10.

# %%
learning_rates = [0.0001, 0.001, 0.01, 0.1, 1, 5]

for lr in learning_rates:
    model = initialize_model()
    start_time = time.time()
    
    optimizer = optimizers.Adam(learning_rate=lr)
    compile_model(model, optimizer)

    es = EarlyStopping(patience=10, restore_best_weights=True)

    history = model.fit(X_train, y_train, 
                      batch_size=16, 
                      epochs=500, 
                      validation_split=0.3,
                      callbacks=[es], verbose=0)

    res = model.evaluate(X_test, y_test)[1]

    print(f'MAE with the {optimizer} optimizer: {res:.4f}  reached in {(end_time - start_time):.0f} s after {len(history.epoch)} epochs')
    plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 0s/step - loss: 31.8671 - accuracy: 0.0000e+00 - mae: 4.2030 - mse: 31.8671
# MAE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CD849A2B0> optimizer: 0.0000  reached in -2143 s after 500 epochs
# 4/4 [==============================] - 0s 5ms/step - loss: 18.7654 - accuracy: 0.0000e+00 - mae: 2.8290 - mse: 18.7654
# MAE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CD83D2310> optimizer: 0.0000  reached in -2171 s after 361 epochs
# 4/4 [==============================] - 0s 0s/step - loss: 17.3764 - accuracy: 0.0000e+00 - mae: 2.8180 - mse: 17.3764
# MAE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CDC8BE490> optimizer: 0.0000  reached in -2194 s after 62 epochs
# 4/4 [==============================] - 0s 2ms/step - loss: 19.5110 - accuracy: 0.0000e+00 - mae: 2.8986 - mse: 19.5110
# MAE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CDB0E93A0> optimizer: 0.0000  reached in -2199 s after 29 epochs
# 4/4 [==============================] - 0s 5ms/step - loss: 83.7812 - accuracy: 0.0000e+00 - mae: 6.5301 - mse: 83.7812
# MAE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CDFEBA4F0> optimizer: 0.0000  reached in -2202 s after 15 epochs
# 4/4 [==============================] - 0s 5ms/step - loss: 84.3919 - accuracy: 0.0000e+00 - mae: 6.5140 - mse: 84.3919
# MAE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CD057EC10> optimizer: 0.0000  reached in -2204 s after 65 epochs

# %% [markdown]
# # 3. The loss
#
# ⚠️ It is important to **clearly understand the different between metrics and losses**.
#
# * The `loss functions` are computed *during* the training procedure
# * The `metrics` are computed *after* training your models !
# * Some metrics can be used as loss functions too... as long as they are differentiable ! (e.g. the *MSE*)
#
# ❓ **Question** ❓ Run the same neural network, once with the `mae` as the loss, and once with the `mse`.
#
# In both case, compare `mae_train`, `mae_val`, `mse_train`, `mse_val` and conclude.

# %%
def compile_model_l(model, optimizer_name,loss_name):
    
    model.compile(loss=loss_name, metrics=['accuracy','mae','mse'], optimizer= optimizer_name)
    
    return model

# %%
model = initialize_model()
compile_model_l(model, "adam", "mae")
es = EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, 
                  batch_size=16, 
                  epochs=500, 
                  validation_split=0.3,
                  callbacks=[es], verbose=0)

res = model.evaluate(X_test, y_test)[1]

print(f'MAE with the {optimizer} optimizer: {res:.4f}  reached in {(end_time - start_time):.0f} s after {len(history.epoch)} epochs')
plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0542 - accuracy: 0.0000e+00 - mae: 3.0542 - mse: 21.3504
# MAE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CD2EA2730> optimizer: 0.0000  reached in -154 s after 166 epochs

# %%
model = initialize_model()
compile_model_l(model, "adam", "mse")
es = EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, 
                  batch_size=16, 
                  epochs=500, 
                  validation_split=0.3,
                  callbacks=[es], verbose=0)

res = model.evaluate(X_test, y_test)[1]

print(f'MSE with the {optimizer} optimizer: {res:.4f}  reached in {(end_time - start_time):.0f} s after {len(history.epoch)} epochs')
plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 0s/step - loss: 18.2583 - accuracy: 0.0000e+00 - mae: 2.8871 - mse: 18.2583
# MSE with the <keras.optimizers.optimizer_experimental.adam.Adam object at 0x0000019CD057EC10> optimizer: 0.0000  reached in -2204 s after 258 epochs

# %% [markdown]
# ❗️ Countrary to first intuition, it can be sometimes better to use the MSE as the loss function in order to get the best MAE possible in the end!
#
# <details>
#     <summary>▶ Why?</summary>
#
# Well, even the Deep Learning research community is still trying to answer these types of questions rigorously.
#
# One thing for sure: In Deep Learning, you will never really reach the "global minimum" of the true loss function (the one computed using your entire training set as one single "batch"). So, in your first model (minimizing the MAE loss), your global MAE minimum has clearly **not** been reached (otherwise you could never beat it).
#
# Why? It may well be that the minimization process of the second model has performed better. Maybe because the loss function "energy map" is "smoother" or more "convex" in the case of MSE loss? Or maybe your hyper-parameter are best suited to the MSE than to the MAE loss?
#
# </details>

# %% [markdown]
# ### 🧪 Test your model best performance
#
# ❓ Save your best model performance on the test set at `mae_test` and check it out below

# %%
model.save('mae_test')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: mae_test\assets
# INFO:tensorflow:Assets written to: mae_test\assets

# %% [markdown]
# # 4 : Save and load a model
#
# ❓ **Question** ❓  Save your model using `.save_model(model, 'name_of_my_model')` method that you can find [here](https://www.tensorflow.org/api_docs/python/tf/keras/models/save_model)..

# %% [markdown]
# ❓ **Question** ❓ Now, in a variable that you will call `loaded_model`, load the model you just saved thanks to `.load_model('name_of_your_model')` [(documentation here)](https://www.tensorflow.org/api_docs/python/tf/keras/models/load_model), and evaluate it on the test data to check that it gives the same result as before.

# %%
loaded_model = keras.models.load_model('mae_test')

# %% [markdown]
# ## (Optional) `Exponential Decay` for the Optimizer's Learning Rate
#
# The next question is not essential and can be skipped as many algorithms can be run without such optimization.
#
# Instead of keeping a fixed learning rate, you can change it from one iteration to the other, with the intuition that at first, you need large learning rates, and as the neural network converges and get closer to the minimum loss value, you can decrease the value of the learning rate. This is called a **`scheduler`**.
#
# ❓ **Question** ❓ Use the [Exponential Decay Scheduler](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/ExponentialDecay) in the `adam` optimizer and run it on the previous data. Start with the following:
#
# ```python
# initial_learning_rate = 0.001 # start with default ADAM value
#
# lr_schedule = ExponentialDecay(
#     # Every 5000 iterations, multiply the learning rate by 0.7
#     initial_learning_rate, decay_steps=5000, decay_rate=0.7,
# )
# ```

# %%
# YOUR CODE HERE
